# %% [markdown]
# # Bank Marketing Dataset - Clustering
# ## 1.Data-preprocessing
#
# * Krzysztof Sawicki
# * Michał Geneja
# * Natalia Safiejko
#
# [Dane](https://www.kaggle.com/datasets/hariharanpavan/bank-marketing-dataset-analysis-classification?resource=download)

# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
from sklearn.model_selection import train_test_split
from sklearn import preprocessing

np.random.seed = 23

# %%
df = pd.read_csv('data/bank.csv')

# %% [markdown]
# ## 1. Zapoznanie się ze zbiorem danych

# %%
df.head()
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome
# 0  unknown    5   may       261         1     -1         0  unknown
# 1  unknown    5   may       151         1     -1         0  unknown
# 2  unknown    5   may        76         1     -1         0  unknown
# 3  unknown    5   may        92         1     -1         0  unknown
# 4  unknown    5   may       198         1     -1         0  unknown

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 16 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        45211 non-null  int64
#  1   job        45211 non-null  object
#  2   marital    45211 non-null  object
#  3   education  45211 non-null  object
#  4   default    45211 non-null  object
#  5   balance    45211 non-null  int64
#  6   housing    45211 non-null  object
#  7   loan       45211 non-null  object
#  8   contact    45211 non-null  object
#  9   day        45211 non-null  int64
#  10  month      45211 non-null  object
#  11  duration   45211 non-null  int64
#  12  campaign   45211 non-null  int64
#  13  pdays      45211 non-null  int64
#  14  previous   45211 non-null  int64
#  15  poutcome   45211 non-null  object
# dtypes: int64(7), object(9)
# memory usage: 5.5+ MB

# %%
df.describe()
# Out:
#                 age        balance           day      duration      campaign  \
# count  45211.000000   45211.000000  45211.000000  45211.000000  45211.000000
# mean      40.936210    1362.272058     15.806419    258.163080      2.763841
# std       10.618762    3044.765829      8.322476    257.527812      3.098021
# min       18.000000   -8019.000000      1.000000      0.000000      1.000000
# 25%       33.000000      72.000000      8.000000    103.000000      1.000000
# 50%       39.000000     448.000000     16.000000    180.000000      2.000000
# 75%       48.000000    1428.000000     21.000000    319.000000      3.000000
# max       95.000000  102127.000000     31.000000   4918.000000     63.000000
#
#               pdays      previous
# count  45211.000000  45211.000000
# mean      40.197828      0.580323
# std      100.128746      2.303441
# min       -1.000000      0.000000
# 25%       -1.000000      0.000000
# 50%       -1.000000      0.000000
# 75%       -1.000000      0.000000
# max      871.000000    275.000000

# %%
df.isna().sum().sum()
# Out:
# 0

# %%
df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome'],
#       dtype='object')

# %% [markdown]
# ## 2.Podział danych
#
# Podziału danych dokonaliśmy przy pomocy poniższej funkcji:

# %%
def split_dataset(df: pd.DataFrame) -> tuple:
    """
    Function to split dataset into training and validation subsets
    :param df: Data frame to be split
    :return: Tuple of training and validation datasets
    """
    x_train1, x_test = train_test_split(df, test_size=0.3, random_state=10)
    x_train, x_valid = train_test_split(x_train1, test_size=0.3, random_state=10)
    return x_train, x_valid, x_test

x_train, x_valid, x_test = split_dataset(df)

# %% [markdown]
# ## 3. Transformacja data frame

# %% [markdown]
# Zamiana słów na liczby

# %%
def switch_for_numbers(column):
    
    """
    Function to switch strings into numbers
    :param column: column of dataframe with strings
    :return: Modified column
    """
    unique_value = list(set(column))  
    dic = {value: indeks for indeks, value in enumerate(unique_value)}  
    

    numbers_column = [dic[value] for value in column]
    
    return numbers_column

# %%
x_train.loc[:,"job"].unique()
# Out:
# array(['technician', 'admin.', 'entrepreneur', 'blue-collar',
#        'management', 'retired', 'self-employed', 'housemaid', 'services',
#        'unknown', 'unemployed', 'student'], dtype=object)

# %%
x_train.loc[:,"job"] = switch_for_numbers(x_train.loc[:,"job"])

# %%
x_train.loc[:,"marital"].unique()
# Out:
# array(['married', 'single', 'divorced'], dtype=object)

# %%
x_train.loc[:,"marital"] = switch_for_numbers(x_train.loc[:,"marital"])

# %%
x_train.loc[:,"education"].unique()
# Out:
# array(['secondary', 'tertiary', 'primary', 'unknown'], dtype=object)

# %%
x_train.loc[:,"education"] = switch_for_numbers(x_train.loc[:,"education"])

# %%
x_train.loc[:,"default"].unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %%
x_train.loc[:,"default"] = [0 if value == 'no' else 1 for value in x_train.loc[:,"default"]]

# %%
x_train.loc[:,"housing"].unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %%
x_train.loc[:,"housing"] = [0 if value == 'no' else 1 for value in x_train.loc[:,"housing"]]

# %%
x_train.loc[:,"loan"].unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %%
x_train.loc[:,"loan"] = [0 if value == 'no' else 1 for value in x_train.loc[:,"loan"]]

# %%
x_train.loc[:,"contact"].unique()
# Out:
# array(['cellular', 'unknown', 'telephone'], dtype=object)

# %%
x_train.loc[:,"contact"] = switch_for_numbers(x_train.loc[:,"contact"])

# %%
x_train.loc[:,"month"].unique()
# Out:
# array(['aug', 'jun', 'feb', 'jul', 'may', 'nov', 'sep', 'apr', 'mar',
#        'oct', 'jan', 'dec'], dtype=object)

# %%
month = ['jan', 'feb', 'mar', 'apr', 'may', 'jun', 'jul', 'aug', 'sep', 'oct', 'nov', 'dec']
x_train.loc[:,"month"] = [month.index(name.lower()) + 1 for name in x_train.loc[:,"month"]]

# %%
x_train.loc[:,"poutcome"].unique()
# Out:
# array(['unknown', 'other', 'failure', 'success'], dtype=object)

# %%
x_train.loc[:,"poutcome"] = switch_for_numbers(x_train.loc[:,"poutcome"])

# %%
x_train.head()
# Out:
#        age  job  marital  education  default  balance  housing  loan  contact  \
# 23000   54    3        0          2        0      965        0     0        0
# 23218   39    3        2          1        0        0        0     0        0
# 21027   36    3        2          1        0      306        0     0        0
# 9895    36    8        2          2        0    13698        0     0        2
# 10688   37    0        0          1        0      264        1     1        2
#
#        day  month  duration  campaign  pdays  previous  poutcome
# 23000   26      8       345         4     -1         0         1
# 23218   27      8       147         4     -1         0         1
# 21027   14      8       111         2     -1         0         1
# 9895     9      6       136         1     -1         0         1
# 10688   16      6       220         1     -1         0         1

# %%
x_train.describe()
# Out:
#                 age           job       marital     education       default  \
# count  22152.000000  22152.000000  22152.000000  22152.000000  22152.000000
# mean      40.898655      4.594122      0.682647      1.440547      0.017831
# std       10.676887      2.928425      0.885403      0.793230      0.132341
# min       18.000000      0.000000      0.000000      0.000000      0.000000
# 25%       33.000000      2.000000      0.000000      1.000000      0.000000
# 50%       39.000000      3.000000      0.000000      2.000000      0.000000
# 75%       48.000000      6.000000      2.000000      2.000000      0.000000
# max       95.000000     11.000000      2.000000      3.000000      1.000000
#
#              balance       housing          loan       contact           day  \
# count   22152.000000  22152.000000  22152.000000  22152.000000  22152.000000
# mean     1385.776363      0.556022      0.160347      0.637505     15.774828
# std      3197.835550      0.496863      0.366936      0.896956      8.319592
# min     -6847.000000      0.000000      0.000000      0.000000      1.000000
# 25%        70.000000      0.000000      0.000000      0.000000      8.000000
# 50%       453.000000      1.000000      0.000000      0.000000     16.000000
# 75%      1436.250000      1.000000      0.000000      2.000000     21.000000
# max    102127.000000      1.000000      1.000000      2.000000     31.000000
#
#               month      duration      campaign         pdays      previous  \
# count  22152.000000  22152.000000  22152.000000  22152.000000  22152.000000
# mean       6.140845    258.690051      2.775235     39.569520      0.563516
# std        2.395206    259.505514      3.087866     99.515152      1.867159
# min        1.000000      0.000000      1.000000     -1.000000      0.000000
# 25%        5.000000    103.000000      1.000000     -1.000000      0.000000
# 50%        6.000000    179.000000      2.000000     -1.000000      0.000000
# 75%        8.000000    319.250000      3.000000     -1.000000      0.000000
# max       12.000000   3881.000000     63.000000    842.000000     41.000000
#
#            poutcome
# count  22152.000000
# mean       1.132494
# std        0.512413
# min        0.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.000000
# max        3.000000

# %% [markdown]
# ### Outliery

# %% [markdown]
# Procesowi usunięcia outlierów nie będą podlegały takie kolumny jak date czy month, gdyż posiadają one poprawne dane

# %%
def substitute_outliers(df: pd.DataFrame, median: dict[str:float] = None, upper_lim: dict[str:float] = None, lower_lim: dict[str:float] = None) -> tuple:
    """
    Function to substitute outliers with median value
    :param df: Data frame to modify
    :return: Modified data frame
    """
    if median is None:
        median = {}
    if upper_lim is None:
        upper_lim = {}
    if lower_lim is None:
        lower_lim = {}
    for col in df:
        if median.get(col, None) is None:
            median[col] = df[col].median()
        if upper_lim.get(col, None) is None:
            upper_lim[col] = df[col].quantile(.995)
        if lower_lim.get(col, None) is None:
            lower_lim[col] = df[col].quantile(.005)
        outliers = (df[col] > upper_lim[col]) | (df[col] < lower_lim[col])
        df[col][outliers]=np.nan
        df.replace({np.nan:median[col]}, inplace=True)
        
    return df, median, upper_lim, lower_lim

# %% [markdown]
# Wybieramy kolumny, które w oryginalnej ramce danych były numeryczne

# %%
numeric_columns = ['balance','duration','campaign','pdays', 'previous', 'poutcome']

# %%
x_train.loc[:,numeric_columns], median, upper_lim, lower_lim = substitute_outliers(x_train.loc[:,numeric_columns])
x_train.describe()
# Out:
#                 age           job       marital     education       default  \
# count  22152.000000  22152.000000  22152.000000  22152.000000  22152.000000
# mean      40.898655      4.594122      0.682647      1.440547      0.017831
# std       10.676887      2.928425      0.885403      0.793230      0.132341
# min       18.000000      0.000000      0.000000      0.000000      0.000000
# 25%       33.000000      2.000000      0.000000      1.000000      0.000000
# 50%       39.000000      3.000000      0.000000      2.000000      0.000000
# 75%       48.000000      6.000000      2.000000      2.000000      0.000000
# max       95.000000     11.000000      2.000000      3.000000      1.000000
#
#             balance       housing          loan       contact           day  \
# count  22152.000000  22152.000000  22152.000000  22152.000000  22152.000000
# mean    1175.081212      0.556022      0.160347      0.637505     15.774828
# std     1928.661827      0.496863      0.366936      0.896956      8.319592
# min     -637.000000      0.000000      0.000000      0.000000      1.000000
# 25%       80.000000      0.000000      0.000000      0.000000      8.000000
# 50%      453.000000      1.000000      0.000000      0.000000     16.000000
# 75%     1373.000000      1.000000      0.000000      2.000000     21.000000
# max    13308.000000      1.000000      1.000000      2.000000     31.000000
#
#               month      duration      campaign         pdays      previous  \
# count  22152.000000  22152.000000  22152.000000  22152.000000  22152.000000
# mean       6.140845    245.212441      2.588299     35.690547      0.446145
# std        2.395206    211.229977      2.297098     90.814139      1.248461
# min        1.000000     11.000000      1.000000     -1.000000      0.000000
# 25%        5.000000    106.000000      1.000000     -1.000000      0.000000
# 50%        6.000000    179.000000      2.000000     -1.000000      0.000000
# 75%        8.000000    310.000000      3.000000     -1.000000      0.000000
# max       12.000000   1290.000000     17.000000    370.000000      9.000000
#
#            poutcome
# count  22152.000000
# mean       1.132494
# std        0.512413
# min        0.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.000000
# max        3.000000

# %% [markdown]
# ### Normalizacja

# %%
def normalization(df: pd.DataFrame, minimums: dict[str:float] = None, maximums: dict[str:float] = None) -> tuple[pd.DataFrame, dict[str:float], dict[str:float]]:
    """
    Function to normalize pandas dataframe using min-max scaling
    :param df: Data frame to normalize
    :param minimums: Dictionary of minimums of columns. Needed for validation
    :param maximums: Dictionary of maximums of columns. Needed for validation
    :return: Normalized data frame, followed by dictionaries of minimums and maximums
    """
    if minimums is None:
        minimums = {col:df[col].min() for col in df.columns}
    if maximums is None:
        maximums = {col:df[col].max() for col in df.columns}
    for column in df.columns:
        df[column] = (df[column] - minimums[column]) / (maximums[column] - minimums[column])
    return df, minimums, maximums

# %%
x_train, minimums, maximums = normalization(x_train)
x_train.describe()
# Out:
#                 age           job       marital     education       default  \
# count  22152.000000  22152.000000  22152.000000  22152.000000  22152.000000
# mean       0.297385      0.417647      0.341324      0.480182      0.017831
# std        0.138661      0.266220      0.442701      0.264410      0.132341
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.194805      0.181818      0.000000      0.333333      0.000000
# 50%        0.272727      0.272727      0.000000      0.666667      0.000000
# 75%        0.389610      0.545455      1.000000      0.666667      0.000000
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
#             balance       housing          loan       contact           day  \
# count  22152.000000  22152.000000  22152.000000  22152.000000  22152.000000
# mean       0.129945      0.556022      0.160347      0.318752      0.492494
# std        0.138305      0.496863      0.366936      0.448478      0.277320
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.051416      0.000000      0.000000      0.000000      0.233333
# 50%        0.078164      1.000000      0.000000      0.000000      0.500000
# 75%        0.144138      1.000000      0.000000      1.000000      0.666667
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
#               month      duration      campaign         pdays      previous  \
# count  22152.000000  22152.000000  22152.000000  22152.000000  22152.000000
# mean       0.467350      0.183122      0.099269      0.098896      0.049572
# std        0.217746      0.165152      0.143569      0.244782      0.138718
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.363636      0.074277      0.000000      0.000000      0.000000
# 50%        0.454545      0.131353      0.062500      0.000000      0.000000
# 75%        0.636364      0.233776      0.125000      0.000000      0.000000
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
#            poutcome
# count  22152.000000
# mean       0.377498
# std        0.170804
# min        0.000000
# 25%        0.333333
# 50%        0.333333
# 75%        0.333333
# max        1.000000

# %% [markdown]
# ## Korelacja

# %%
corr = x_train.corr('spearman')
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_aed2c_row0_col0, #T_aed2c_row1_col1, #T_aed2c_row2_col2, #T_aed2c_row3_col3, #T_aed2c_row4_col4, #T_aed2c_row5_col5, #T_aed2c_row6_col6, #T_aed2c_row7_col7, #T_aed2c_row8_col8, #T_aed2c_row9_col9, #T_aed2c_row10_col10, #T_aed2c_row11_col11, #T_aed2c_row12_col12, #T_aed2c_row13_col13, #T_aed2c_row14_col14, #T_aed2c_row15_col15 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_aed2c_row0_col1, #T_aed2c_row6_col4, #T_aed2c_row9_col5 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_aed2c_row0_col2, #T_aed2c_row0_col3, #T_aed2c_row2_col0, #T_aed2c_row4_col5, #T_aed2c_row5_col4, #T_aed2c_row5_col7, #T_aed2c_row6_col1, #T_aed2c_row6_col10, #T_aed2c_row8_col13, #T_aed2c_row8_col14, #T_aed2c_row8_col15, #T_aed2c_row10_col1, #T_aed2c_row10_col6, #T_aed2c_row12_col11, #T_aed2c_row13_col8, #T_aed2c_row13_col9, #T_aed2c_row14_col8, #T_aed2c_row14_col12 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_aed2c_row0_col4, #T_aed2c_row8_col1, #T_aed2c_row11_col3, #T_aed2c_row14_col3 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_aed2c_row0_col5, #T_aed2c_row4_col6, #T_aed2c_row11_col6 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_aed2c_row0_col6, #T_aed2c_row3_col12, #T_aed2c_row4_col11, #T_aed2c_row5_col12 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_aed2c_row0_col7, #T_aed2c_row3_col5, #T_aed2c_row3_col9, #T_aed2c_row5_col9, #T_aed2c_row7_col9, #T_aed2c_row9_col3, #T_aed2c_row15_col8 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_aed2c_row0_col8, #T_aed2c_row1_col8, #T_aed2c_row4_col0, #T_aed2c_row5_col2 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_aed2c_row0_col9, #T_aed2c_row1_col7, #T_aed2c_row1_col12, #T_aed2c_row6_col5, #T_aed2c_row15_col7 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_aed2c_row0_col10, #T_aed2c_row9_col10 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_aed2c_row0_col11, #T_aed2c_row2_col7 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_aed2c_row0_col12, #T_aed2c_row1_col3, #T_aed2c_row2_col4, #T_aed2c_row9_col13 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_aed2c_row0_col13, #T_aed2c_row0_col14, #T_aed2c_row2_col6, #T_aed2c_row9_col8, #T_aed2c_row10_col12 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_aed2c_row0_col15 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_aed2c_row1_col0 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_aed2c_row1_col2, #T_aed2c_row5_col13, #T_aed2c_row14_col0 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_aed2c_row1_col4, #T_aed2c_row4_col12, #T_aed2c_row7_col3, #T_aed2c_row10_col13, #T_aed2c_row10_col15, #T_aed2c_row11_col4 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_aed2c_row1_col5, #T_aed2c_row2_col3, #T_aed2c_row9_col4, #T_aed2c_row10_col4, #T_aed2c_row10_col14, #T_aed2c_row12_col4, #T_aed2c_row12_col13 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_aed2c_row1_col6, #T_aed2c_row4_col7, #T_aed2c_row5_col6 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_aed2c_row1_col9, #T_aed2c_row6_col9, #T_aed2c_row8_col9, #T_aed2c_row8_col11, #T_aed2c_row10_col8, #T_aed2c_row12_col3 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_aed2c_row1_col10, #T_aed2c_row3_col10, #T_aed2c_row10_col5, #T_aed2c_row11_col10, #T_aed2c_row15_col5 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_aed2c_row1_col11, #T_aed2c_row3_col11, #T_aed2c_row8_col12, #T_aed2c_row12_col5 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_aed2c_row1_col13, #T_aed2c_row2_col13 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_aed2c_row1_col14, #T_aed2c_row2_col14 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_aed2c_row1_col15, #T_aed2c_row6_col0 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_aed2c_row2_col1 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_aed2c_row2_col5, #T_aed2c_row8_col3, #T_aed2c_row9_col7, #T_aed2c_row12_col7, #T_aed2c_row13_col3, #T_aed2c_row13_col10, #T_aed2c_row15_col4 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_aed2c_row2_col8, #T_aed2c_row14_col5, #T_aed2c_row15_col10 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_aed2c_row2_col9, #T_aed2c_row7_col11, #T_aed2c_row8_col7, #T_aed2c_row11_col7, #T_aed2c_row13_col1, #T_aed2c_row14_col1 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_aed2c_row2_col10, #T_aed2c_row3_col4, #T_aed2c_row3_col15, #T_aed2c_row9_col14 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_aed2c_row2_col11, #T_aed2c_row3_col7, #T_aed2c_row7_col15, #T_aed2c_row10_col7, #T_aed2c_row12_col14, #T_aed2c_row13_col11 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_aed2c_row2_col12, #T_aed2c_row8_col10, #T_aed2c_row12_col15 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_aed2c_row2_col15, #T_aed2c_row6_col7, #T_aed2c_row8_col4 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_aed2c_row3_col0, #T_aed2c_row7_col8, #T_aed2c_row12_col9 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_aed2c_row3_col1, #T_aed2c_row4_col3, #T_aed2c_row7_col12 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_aed2c_row3_col2 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_aed2c_row3_col6, #T_aed2c_row7_col6, #T_aed2c_row8_col2, #T_aed2c_row11_col0, #T_aed2c_row11_col14 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_aed2c_row3_col8, #T_aed2c_row3_col13, #T_aed2c_row7_col10, #T_aed2c_row12_col2 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_aed2c_row3_col14, #T_aed2c_row4_col8 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_aed2c_row4_col1, #T_aed2c_row10_col3, #T_aed2c_row11_col9, #T_aed2c_row15_col9 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_aed2c_row4_col2 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_aed2c_row4_col9, #T_aed2c_row6_col11, #T_aed2c_row8_col5, #T_aed2c_row9_col15, #T_aed2c_row13_col4, #T_aed2c_row14_col4, #T_aed2c_row15_col3 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_aed2c_row4_col10, #T_aed2c_row9_col12, #T_aed2c_row12_col8, #T_aed2c_row15_col6 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_aed2c_row4_col13, #T_aed2c_row7_col4, #T_aed2c_row7_col14, #T_aed2c_row11_col8 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_aed2c_row4_col14, #T_aed2c_row5_col8, #T_aed2c_row9_col6 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_aed2c_row4_col15 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_aed2c_row5_col0 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_aed2c_row5_col1 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_aed2c_row5_col3, #T_aed2c_row9_col11, #T_aed2c_row10_col11 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_aed2c_row5_col10 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_aed2c_row5_col11, #T_aed2c_row6_col3, #T_aed2c_row14_col10, #T_aed2c_row14_col11, #T_aed2c_row15_col11 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_aed2c_row5_col14, #T_aed2c_row6_col2, #T_aed2c_row6_col14, #T_aed2c_row9_col0 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_aed2c_row5_col15 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_aed2c_row6_col8 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_aed2c_row6_col12, #T_aed2c_row11_col1 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_aed2c_row6_col13, #T_aed2c_row15_col0 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_aed2c_row6_col15 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_aed2c_row7_col0, #T_aed2c_row9_col2 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_aed2c_row7_col1, #T_aed2c_row7_col5 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_aed2c_row7_col2, #T_aed2c_row11_col13 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_aed2c_row7_col13, #T_aed2c_row10_col9 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_aed2c_row8_col0 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_aed2c_row8_col6 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_aed2c_row9_col1 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_aed2c_row10_col0 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_aed2c_row1

# %%
def drop_correlated_columns(df: pd.DataFrame, cut_off: float = 0.8, to_drop:list[str]=None) -> tuple[pd.DataFrame,list[str]]:
    """
    Function to drop correlated columns of a Data Frame
    :param df: Data frame to be modified
    :param cut_off: Maximum allowed correlation
    :param to_drop: Columns to drop. By default, those with 0 variation
    :return: Data frame with deleted correlated columns, list of dropped columns
    """
    if to_drop is None:
        corr_matrix = df.corr('spearman').abs()
        upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(bool))
        to_drop = [column for column in upper.columns if any(upper[column] > cut_off)]
    df.drop(to_drop, axis=1, inplace=True)
    return df, to_drop

# %%
x_train, to_drop = drop_correlated_columns(x_train)

# %%
print(to_drop)
# Out:
# ['previous']

# %%
#zapisy
x_train.to_csv('data/x_train.csv', index=False)
#x_test.to_csv('x_test.csv', index=False)

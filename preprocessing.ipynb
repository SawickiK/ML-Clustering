# %% [markdown]
# # Bank Marketing Dataset - Clustering
# ## 1.Data-preprocessing
#
# * Krzysztof Sawicki
# * Michał Geneja
# * Natalia Safiejko
#
# [Dane](https://www.kaggle.com/datasets/hariharanpavan/bank-marketing-dataset-analysis-classification?resource=download)

# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
from sklearn.model_selection import train_test_split
from sklearn import preprocessing

np.random.seed = 23

# %%
df = pd.read_csv('data/bank.csv')

# %% [markdown]
# ## 1. Zapoznanie się ze zbiorem danych

# %%
df.head()
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome
# 0  unknown    5   may       261         1     -1         0  unknown
# 1  unknown    5   may       151         1     -1         0  unknown
# 2  unknown    5   may        76         1     -1         0  unknown
# 3  unknown    5   may        92         1     -1         0  unknown
# 4  unknown    5   may       198         1     -1         0  unknown

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 16 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        45211 non-null  int64
#  1   job        45211 non-null  object
#  2   marital    45211 non-null  object
#  3   education  45211 non-null  object
#  4   default    45211 non-null  object
#  5   balance    45211 non-null  int64
#  6   housing    45211 non-null  object
#  7   loan       45211 non-null  object
#  8   contact    45211 non-null  object
#  9   day        45211 non-null  int64
#  10  month      45211 non-null  object
#  11  duration   45211 non-null  int64
#  12  campaign   45211 non-null  int64
#  13  pdays      45211 non-null  int64
#  14  previous   45211 non-null  int64
#  15  poutcome   45211 non-null  object
# dtypes: int64(7), object(9)
# memory usage: 5.5+ MB

# %%
df.describe()
# Out:
#                 age        balance           day      duration      campaign  \
# count  45211.000000   45211.000000  45211.000000  45211.000000  45211.000000
# mean      40.936210    1362.272058     15.806419    258.163080      2.763841
# std       10.618762    3044.765829      8.322476    257.527812      3.098021
# min       18.000000   -8019.000000      1.000000      0.000000      1.000000
# 25%       33.000000      72.000000      8.000000    103.000000      1.000000
# 50%       39.000000     448.000000     16.000000    180.000000      2.000000
# 75%       48.000000    1428.000000     21.000000    319.000000      3.000000
# max       95.000000  102127.000000     31.000000   4918.000000     63.000000
#
#               pdays      previous
# count  45211.000000  45211.000000
# mean      40.197828      0.580323
# std      100.128746      2.303441
# min       -1.000000      0.000000
# 25%       -1.000000      0.000000
# 50%       -1.000000      0.000000
# 75%       -1.000000      0.000000
# max      871.000000    275.000000

# %%
df.isna().sum().sum()
# Out:
# 0

# %%
df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome'],
#       dtype='object')

# %% [markdown]
# ## 2.Podział danych
#
# Podziału danych dokonaliśmy przy pomocy poniższej funkcji:

# %%
def split_dataset(df: pd.DataFrame) -> tuple:
    """
    Function to split dataset into training and validation subsets
    :param df: Data frame to be split
    :return: Tuple of training and validation datasets
    """
    x_train1, x_test = train_test_split(df, test_size=0.3, random_state=10)
    x_train, x_valid = train_test_split(x_train1, test_size=0.3, random_state=10)
    return x_train, x_valid, x_test

x_train, x_valid, x_test = split_dataset(df)

# %% [markdown]
# ## 3. Transformacja data frame

# %% [markdown]
# Zamiana słów na liczby

# %%
def switch_for_numbers(column):
    
    """
    Function to switch strings into numbers
    :param column: column of dataframe with strings
    :return: Modified column
    """
    unique_value = list(set(column))  
    dic = {value: indeks for indeks, value in enumerate(unique_value)}  
    

    numbers_column = [dic[value] for value in column]
    
    return numbers_column

# %%
def perform_one_hot_encoding(df, column_list):
    for column in column_list:
        encoded_df = pd.get_dummies(df[column], prefix=column)
        df = pd.concat([df, encoded_df], axis=1)
    return df

# %%
columns_to_encode = ['job', 'marital', 'education','contact', 'poutcome']
x_train = perform_one_hot_encoding(x_train, columns_to_encode)
x_train = x_train.drop(columns_to_encode, axis = 'columns')
x_test = perform_one_hot_encoding(x_test, columns_to_encode)
x_test = x_test.drop(columns_to_encode, axis = 'columns')

# %%
x_train.columns
# Out:
# Index(['age', 'default', 'balance', 'housing', 'loan', 'day', 'month',
#        'duration', 'campaign', 'pdays', 'previous', 'job_admin.',
#        'job_blue-collar', 'job_entrepreneur', 'job_housemaid',
#        'job_management', 'job_retired', 'job_self-employed', 'job_services',
#        'job_student', 'job_technician', 'job_unemployed', 'job_unknown',
#        'marital_divorced', 'marital_married', 'marital_single',
#        'education_primary', 'education_secondary', 'education_tertiary',
#        'education_unknown', 'contact_cellular', 'contact_telephone',
#        'contact_unknown', 'poutcome_failure', 'poutcome_other',
#        'poutcome_success', 'poutcome_unknown'],
#       dtype='object')

# %%
x_train.loc[:,"default"].unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %%
x_train.loc[:,"default"] = [0 if value == 'no' else 1 for value in x_train.loc[:,"default"]]
x_test.loc[:,"default"] = [0 if value == 'no' else 1 for value in x_test.loc[:,"default"]]

# %%
x_train.loc[:,"housing"].unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %%
x_train.loc[:,"housing"] = [0 if value == 'no' else 1 for value in x_train.loc[:,"housing"]]
x_test.loc[:,"housing"] = [0 if value == 'no' else 1 for value in x_test.loc[:,"housing"]]

# %%
x_train.loc[:,"loan"].unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %%
x_train.loc[:,"loan"] = [0 if value == 'no' else 1 for value in x_train.loc[:,"loan"]]
x_test.loc[:,"loan"] = [0 if value == 'no' else 1 for value in x_test.loc[:,"loan"]]

# %%
x_train.loc[:,"month"].unique()
# Out:
# array(['aug', 'jun', 'feb', 'jul', 'may', 'nov', 'sep', 'apr', 'mar',
#        'oct', 'jan', 'dec'], dtype=object)

# %%
month = ['jan', 'feb', 'mar', 'apr', 'may', 'jun', 'jul', 'aug', 'sep', 'oct', 'nov', 'dec']
x_train.loc[:,"month"] = [month.index(name.lower()) + 1 for name in x_train.loc[:,"month"]]
x_test.loc[:,"month"] = [month.index(name.lower()) + 1 for name in x_test.loc[:,"month"]]

# %%
x_train.head()
# Out:
#        age  default  balance  housing  loan  day  month  duration  campaign  \
# 23000   54        0      965        0     0   26      8       345         4
# 23218   39        0        0        0     0   27      8       147         4
# 21027   36        0      306        0     0   14      8       111         2
# 9895    36        0    13698        0     0    9      6       136         1
# 10688   37        0      264        1     1   16      6       220         1
#
#        pdays  ...  education_secondary  education_tertiary  education_unknown  \
# 23000     -1  ...                    1                   0                  0
# 23218     -1  ...                    0                   1                  0
# 21027     -1  ...                    0                   1                  0
# 9895      -1  ...                    1                   0                  0
# 10688     -1  ...                    0                   1                  0
#
#        contact_cellular  contact_telephone  contact_unknown  poutcome_failure  \
# 23000                 1                  0                0                 0
# 23218                 1                  0                0                 0
# 21027                 1                  0                0                 0
# 9895                  0                  0                1                 0
# 10688                 0                  0                1                 0
#
#        poutcome_other  poutcome_success  poutcome_unknown
# 23000               0                 0                 1
# 23218               0                 0                 1
# 21027               0                 0                 1
# 9895                0                 0                 1
# 10688               0                 0                 1
#
# [5 rows x 37 columns]

# %%
x_train.describe()
# Out:
#                 age       default        balance       housing          loan  \
# count  22152.000000  22152.000000   22152.000000  22152.000000  22152.000000
# mean      40.898655      0.017831    1385.776363      0.556022      0.160347
# std       10.676887      0.132341    3197.835550      0.496863      0.366936
# min       18.000000      0.000000   -6847.000000      0.000000      0.000000
# 25%       33.000000      0.000000      70.000000      0.000000      0.000000
# 50%       39.000000      0.000000     453.000000      1.000000      0.000000
# 75%       48.000000      0.000000    1436.250000      1.000000      0.000000
# max       95.000000      1.000000  102127.000000      1.000000      1.000000
#
#                 day         month      duration      campaign         pdays  \
# count  22152.000000  22152.000000  22152.000000  22152.000000  22152.000000
# mean      15.774828      6.140845    258.690051      2.775235     39.569520
# std        8.319592      2.395206    259.505514      3.087866     99.515152
# min        1.000000      1.000000      0.000000      1.000000     -1.000000
# 25%        8.000000      5.000000    103.000000      1.000000     -1.000000
# 50%       16.000000      6.000000    179.000000      2.000000     -1.000000
# 75%       21.000000      8.000000    319.250000      3.000000     -1.000000
# max       31.000000     12.000000   3881.000000     63.000000    842.000000
#
#        ...  education_secondary  education_tertiary  education_unknown  \
# count  ...         22152.000000        22152.000000       22152.000000
# mean   ...             0.513678            0.294962           0.039410
# std    ...             0.499824            0.456036           0.194572
# min    ...             0.000000            0.000000           0.000000
# 25%    ...             0.000000            0.000000           0.000000
# 50%    ...             1.000000            0.000000           0.000000
# 75%    ...             1.000000            1.000000           0.000000
# max    ...             1.000000            1.000000           1.000000
#
#        contact_cellular  contact_telephone  contact_unknown  poutcome_failure  \
# count      22152.000000       22152.000000     22152.000000      22152.000000
# mean           0.649196           0.064103         0.286701          0.105273
# std            0.477232           0.244941         0.452231          0.306911
# min            0.000000           0.000000         0.000000          0.000000
# 25%            0.000000           0.000000         0.000000          0.000000
# 50%            1.000000           0.000000         0.000000          0.000000
# 75%            1.000000           0.000000         1.000000          0.000000
# max            1.000000           1.000000         1.000000          1.000000
#
#        poutcome_other  poutcome_success  poutcome_unknown
# count    22152.000000      22152.000000      22152.000000
# mean         0.040132          0.033676          0.820919
# std          0.196273          0.180399          0.383429
# min          0.000000          0.000000          0.000000
# 25%          0.000000          0.000000          1.000000
# 50%          0.000000          0.000000          1.000000
# 75%          0.000000          0.000000          1.000000
# max          1.000000          1.000000          1.000000
#
# [8 rows x 37 columns]

# %% [markdown]
# ### Outliery

# %% [markdown]
# Procesowi usunięcia outlierów nie będą podlegały takie kolumny jak date czy month, gdyż posiadają one poprawne dane

# %%
def substitute_outliers(df: pd.DataFrame, median: dict[str:float] = None, upper_lim: dict[str:float] = None, lower_lim: dict[str:float] = None) -> tuple:
    """
    Function to substitute outliers with median value
    :param df: Data frame to modify
    :return: Modified data frame
    """
    if median is None:
        median = {}
    if upper_lim is None:
        upper_lim = {}
    if lower_lim is None:
        lower_lim = {}
    for col in df:
        if median.get(col, None) is None:
            median[col] = df[col].median()
        if upper_lim.get(col, None) is None:
            upper_lim[col] = df[col].quantile(.995)
        if lower_lim.get(col, None) is None:
            lower_lim[col] = df[col].quantile(.005)
        outliers = (df[col] > upper_lim[col]) | (df[col] < lower_lim[col])
        df[col][outliers]=np.nan
        df.replace({np.nan:median[col]}, inplace=True)
        
    return df, median, upper_lim, lower_lim

# %% [markdown]
# Wybieramy kolumny, które w oryginalnej ramce danych były numeryczne

# %%
numeric_columns = ['balance','duration','campaign','pdays', 'previous']

# %%
x_train.loc[:,numeric_columns], median, upper_lim, lower_lim = substitute_outliers(x_train.loc[:,numeric_columns])
x_test.loc[:,numeric_columns], median1, upper_lim2, lower_lim3 = substitute_outliers(x_test.loc[:,numeric_columns],median, upper_lim, lower_lim)
x_train.describe()
# Out:
#                 age       default       balance       housing          loan  \
# count  22152.000000  22152.000000  22152.000000  22152.000000  22152.000000
# mean      40.898655      0.017831   1245.007629      0.556022      0.160347
# std       10.676887      0.132341   2187.268097      0.496863      0.366936
# min       18.000000      0.000000   -892.000000      0.000000      0.000000
# 25%       33.000000      0.000000     76.000000      0.000000      0.000000
# 50%       39.000000      0.000000    453.000000      1.000000      0.000000
# 75%       48.000000      0.000000   1402.000000      1.000000      0.000000
# max       95.000000      1.000000  19313.000000      1.000000      1.000000
#
#                 day         month      duration      campaign         pdays  \
# count  22152.000000  22152.000000  22152.000000  22152.000000  22152.000000
# mean      15.774828      6.140845    250.420414      2.661836     36.905923
# std        8.319592      2.395206    227.150178      2.542509     92.831127
# min        1.000000      1.000000      8.000000      1.000000     -1.000000
# 25%        8.000000      5.000000    104.000000      1.000000     -1.000000
# 50%       16.000000      6.000000    179.000000      2.000000     -1.000000
# 75%       21.000000      8.000000    316.000000      3.000000     -1.000000
# max       31.000000     12.000000   1531.000000     21.000000    392.000000
#
#        ...  education_secondary  education_tertiary  education_unknown  \
# count  ...         22152.000000        22152.000000       22152.000000
# mean   ...             0.513678            0.294962           0.039410
# std    ...             0.499824            0.456036           0.194572
# min    ...             0.000000            0.000000           0.000000
# 25%    ...             0.000000            0.000000           0.000000
# 50%    ...             1.000000            0.000000           0.000000
# 75%    ...             1.000000            1.000000           0.000000
# max    ...             1.000000            1.000000           1.000000
#
#        contact_cellular  contact_telephone  contact_unknown  poutcome_failure  \
# count      22152.000000       22152.000000     22152.000000      22152.000000
# mean           0.649196           0.064103         0.286701          0.105273
# std            0.477232           0.244941         0.452231          0.306911
# min            0.000000           0.000000         0.000000          0.000000
# 25%            0.000000           0.000000         0.000000          0.000000
# 50%            1.000000           0.000000         0.000000          0.000000
# 75%            1.000000           0.000000         1.000000          0.000000
# max            1.000000           1.000000         1.000000          1.000000
#
#        poutcome_other  poutcome_success  poutcome_unknown
# count    22152.000000      22152.000000      22152.000000
# mean         0.040132          0.033676          0.820919
# std          0.196273          0.180399          0.383429
# min          0.000000          0.000000          0.000000
# 25%          0.000000          0.000000          1.000000
# 50%          0.000000          0.000000          1.000000
# 75%          0.000000          0.000000          1.000000
# max          1.000000          1.000000          1.000000
#
# [8 rows x 37 columns]

# %%
x_train.columns
# Out:
# Index(['age', 'default', 'balance', 'housing', 'loan', 'day', 'month',
#        'duration', 'campaign', 'pdays', 'previous', 'job_admin.',
#        'job_blue-collar', 'job_entrepreneur', 'job_housemaid',
#        'job_management', 'job_retired', 'job_self-employed', 'job_services',
#        'job_student', 'job_technician', 'job_unemployed', 'job_unknown',
#        'marital_divorced', 'marital_married', 'marital_single',
#        'education_primary', 'education_secondary', 'education_tertiary',
#        'education_unknown', 'contact_cellular', 'contact_telephone',
#        'contact_unknown', 'poutcome_failure', 'poutcome_other',
#        'poutcome_success', 'poutcome_unknown'],
#       dtype='object')

# %% [markdown]
# ### Normalizacja

# %%
def normalize_dataframe(df, df2):
    dictionary = {}
    normalized_df = df.copy()
    normalized_df2 = df2.copy()
    for column in df.columns:
        column_min = df[column].min()
        column_max = df[column].max()
        values = (column_min, column_max)
        dictionary[column] = values
        normalized_df[column] = (df[column] - column_min) / (column_max - column_min)
        normalized_df2[column] = (df2[column] - column_min) / (column_max - column_min)
    return normalized_df, normalized_df2, dictionary

# %%
x_train, x_test, decode_dict = normalize_dataframe(x_train, x_test)
x_train.describe()
# Out:
#                 age       default       balance       housing          loan  \
# count  22152.000000  22152.000000  22152.000000  22152.000000  22152.000000
# mean       0.297385      0.017831      0.105766      0.556022      0.160347
# std        0.138661      0.132341      0.108254      0.496863      0.366936
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.194805      0.000000      0.047909      0.000000      0.000000
# 50%        0.272727      0.000000      0.066568      1.000000      0.000000
# 75%        0.389610      0.000000      0.113536      1.000000      0.000000
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
#                 day         month      duration      campaign         pdays  \
# count  22152.000000  22152.000000  22152.000000  22152.000000  22152.000000
# mean       0.492494      0.467350      0.159173      0.083092      0.096453
# std        0.277320      0.217746      0.149147      0.127125      0.236212
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.233333      0.363636      0.063033      0.000000      0.000000
# 50%        0.500000      0.454545      0.112278      0.050000      0.000000
# 75%        0.666667      0.636364      0.202232      0.100000      0.000000
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
#        ...  education_secondary  education_tertiary  education_unknown  \
# count  ...         22152.000000        22152.000000       22152.000000
# mean   ...             0.513678            0.294962           0.039410
# std    ...             0.499824            0.456036           0.194572
# min    ...             0.000000            0.000000           0.000000
# 25%    ...             0.000000            0.000000           0.000000
# 50%    ...             1.000000            0.000000           0.000000
# 75%    ...             1.000000            1.000000           0.000000
# max    ...             1.000000            1.000000           1.000000
#
#        contact_cellular  contact_telephone  contact_unknown  poutcome_failure  \
# count      22152.000000       22152.000000     22152.000000      22152.000000
# mean           0.649196           0.064103         0.286701          0.105273
# std            0.477232           0.244941         0.452231          0.306911
# min            0.000000           0.000000         0.000000          0.000000
# 25%            0.000000           0.000000         0.000000          0.000000
# 50%            1.000000           0.000000         0.000000          0.000000
# 75%            1.000000           0.000000         1.000000          0.000000
# max            1.000000           1.000000         1.000000          1.000000
#
#        poutcome_other  poutcome_success  poutcome_unknown
# count    22152.000000      22152.000000      22152.000000
# mean         0.040132          0.033676          0.820919
# std          0.196273          0.180399          0.383429
# min          0.000000          0.000000          0.000000
# 25%          0.000000          0.000000          1.000000
# 50%          0.000000          0.000000          1.000000
# 75%          0.000000          0.000000          1.000000
# max          1.000000          1.000000          1.000000
#
# [8 rows x 37 columns]

# %%
print(decode_dict)
# Out:
# {'age': (18, 95), 'default': (0, 1), 'balance': (-892.0, 19313.0), 'housing': (0, 1), 'loan': (0, 1), 'day': (1, 31), 'month': (1, 12), 'duration': (8.0, 1531.0), 'campaign': (1.0, 21.0), 'pdays': (-1.0, 392.0), 'previous': (0.0, 12.0), 'job_admin.': (0, 1), 'job_blue-collar': (0, 1), 'job_entrepreneur': (0, 1), 'job_housemaid': (0, 1), 'job_management': (0, 1), 'job_retired': (0, 1), 'job_self-employed': (0, 1), 'job_services': (0, 1), 'job_student': (0, 1), 'job_technician': (0, 1), 'job_unemployed': (0, 1), 'job_unknown': (0, 1), 'marital_divorced': (0, 1), 'marital_married': (0, 1), 'marital_single': (0, 1), 'education_primary': (0, 1), 'education_secondary': (0, 1), 'education_tertiary': (0, 1), 'education_unknown': (0, 1), 'contact_cellular': (0, 1), 'contact_telephone': (0, 1), 'contact_unknown': (0, 1), 'poutcome_failure': (0, 1), 'poutcome_other': (0, 1), 'poutcome_success': (0, 1), 'poutcome_unknown': (0, 1)}

# %% [markdown]
# ## Korelacja

# %%
corr = x_train.corr('spearman')
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_e2855_row0_col0, #T_e2855_row1_col1, #T_e2855_row2_col2, #T_e2855_row3_col3, #T_e2855_row4_col4, #T_e2855_row5_col5, #T_e2855_row6_col6, #T_e2855_row7_col7, #T_e2855_row8_col8, #T_e2855_row9_col9, #T_e2855_row10_col10, #T_e2855_row11_col11, #T_e2855_row12_col12, #T_e2855_row13_col13, #T_e2855_row14_col14, #T_e2855_row15_col15, #T_e2855_row16_col16, #T_e2855_row17_col17, #T_e2855_row18_col18, #T_e2855_row19_col19, #T_e2855_row20_col20, #T_e2855_row21_col21, #T_e2855_row22_col22, #T_e2855_row23_col23, #T_e2855_row24_col24, #T_e2855_row25_col25, #T_e2855_row26_col26, #T_e2855_row27_col27, #T_e2855_row28_col28, #T_e2855_row29_col29, #T_e2855_row30_col30, #T_e2855_row31_col31, #T_e2855_row32_col32, #T_e2855_row33_col33, #T_e2855_row34_col34, #T_e2855_row35_col35, #T_e2855_row36_col36 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_e2855_row0_col1, #T_e2855_row2_col17, #T_e2855_row3_col7, #T_e2855_row6_col18, #T_e2855_row7_col21, #T_e2855_row9_col1, #T_e2855_row9_col6, #T_e2855_row12_col7, #T_e2855_row13_col11, #T_e2855_row14_col16, #T_e2855_row17_col8, #T_e2855_row17_col11, #T_e2855_row19_col7, #T_e2855_row19_col18, #T_e2855_row21_col16, #T_e2855_row30_col5, #T_e2855_row31_col5, #T_e2855_row33_col4 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_e2855_row0_col2, #T_e2855_row3_col35, #T_e2855_row8_col20, #T_e2855_row23_col6, #T_e2855_row24_col3, #T_e2855_row29_col22, #T_e2855_row35_col19 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_e2855_row0_col3, #T_e2855_row0_col17, #T_e2855_row2_col8, #T_e2855_row2_col14, #T_e2855_row4_col17, #T_e2855_row5_col14, #T_e2855_row7_col13, #T_e2855_row12_col2, #T_e2855_row16_col3, #T_e2855_row16_col18, #T_e2855_row23_col21, #T_e2855_row29_col14, #T_e2855_row30_col3, #T_e2855_row31_col17, #T_e2855_row32_col14, #T_e2855_row36_col17 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_e2855_row0_col4, #T_e2855_row1_col5, #T_e2855_row1_col17, #T_e2855_row2_col21, #T_e2855_row5_col17, #T_e2855_row9_col17, #T_e2855_row10_col17, #T_e2855_row11_col7, #T_e2855_row13_col7, #T_e2855_row13_col18, #T_e2855_row14_col7, #T_e2855_row14_col18, #T_e2855_row17_col5, #T_e2855_row20_col7, #T_e2855_row21_col18, #T_e2855_row22_col7, #T_e2855_row23_col7, #T_e2855_row23_col8, #T_e2855_row23_col13, #T_e2855_row26_col18, #T_e2855_row33_col7, #T_e2855_row34_col8, #T_e2855_row35_col17, #T_e2855_row35_col21 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_e2855_row0_col5, #T_e2855_row1_col21, #T_e2855_row9_col4, #T_e2855_row11_col5, #T_e2855_row14_col4, #T_e2855_row16_col8, #T_e2855_row18_col5, #T_e2855_row21_col5, #T_e2855_row25_col5, #T_e2855_row25_col17, #T_e2855_row32_col2, #T_e2855_row36_col22 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_e2855_row0_col6, #T_e2855_row3_col23, #T_e2855_row5_col0, #T_e2855_row5_col6, #T_e2855_row8_col15, #T_e2855_row8_col31, #T_e2855_row9_col23, #T_e2855_row10_col23, #T_e2855_row18_col34, #T_e2855_row21_col23, #T_e2855_row22_col26, #T_e2855_row23_col25, #T_e2855_row23_col26, #T_e2855_row28_col34, #T_e2855_row30_col23, #T_e2855_row33_col23, #T_e2855_row36_col23 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_e2855_row0_col7, #T_e2855_row1_col22, #T_e2855_row2_col13, #T_e2855_row3_col8, #T_e2855_row11_col8, #T_e2855_row11_col16, #T_e2855_row12_col5, #T_e2855_row22_col4, #T_e2855_row22_col14, #T_e2855_row22_col21, #T_e2855_row23_col17, #T_e2855_row33_col14, #T_e2855_row33_col21, #T_e2855_row35_col13, #T_e2855_row36_col7 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_e2855_row0_col8, #T_e2855_row2_col7, #T_e2855_row5_col1, #T_e2855_row6_col1, #T_e2855_row10_col7, #T_e2855_row10_col18, #T_e2855_row12_col1, #T_e2855_row15_col29, #T_e2855_row19_col3, #T_e2855_row19_col20, #T_e2855_row26_col19, #T_e2855_row26_col27, #T_e2855_row30_col7, #T_e2855_row31_col3, #T_e2855_row32_col19, #T_e2855_row32_col31, #T_e2855_row33_col16, #T_e2855_row36_col19 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_e2855_row0_col9, #T_e2855_row4_col9, #T_e2855_row11_col36, #T_e2855_row12_col10, #T_e2855_row14_col10, #T_e2855_row24_col9, #T_e2855_row24_col10, #T_e2855_row25_col36, #T_e2855_row29_col32 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_e2855_row0_col10, #T_e2855_row3_col33, #T_e2855_row7_col30, #T_e2855_row18_col32, #T_e2855_row27_col32, #T_e2855_row28_col36, #T_e2855_row30_col28, #T_e2855_row31_col36 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_e2855_row0_col11, #T_e2855_row1_col8, #T_e2855_row6_col11, #T_e2855_row8_col16, #T_e2855_row18_col12, #T_e2855_row19_col11, #T_e2855_row20_col5, #T_e2855_row27_col7, #T_e2855_row28_col8, #T_e2855_row30_col18 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_e2855_row0_col12, #T_e2855_row1_col6, #T_e2855_row13_col3, #T_e2855_row26_col3, #T_e2855_row32_col34 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_e2855_row0_col13, #T_e2855_row0_col22, #T_e2855_row4_col16, #T_e2855_row5_col16, #T_e2855_row6_col14, #T_e2855_row8_col11, #T_e2855_row11_col1, #T_e2855_row12_col4, #T_e2855_row12_col6, #T_e2855_row13_col20, #T_e2855_row14_col8, #T_e2855_row17_col20, #T_e2855_row24_col13, #T_e2855_row25_col2, #T_e2855_row33_col36 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_e2855_row0_col14, #T_e2855_row6_col16, #T_e2855_row9_col29, #T_e2855_row10_col29, #T_e2855_row11_col6, #T_e2855_row13_col12, #T_e2855_row17_col12, #T_e2855_row19_col0, #T_e2855_row21_col6, #T_e2855_row29_col3 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_e2855_row0_col15, #T_e2855_row0_col34, #T_e2855_row2_col23, #T_e2855_row6_col26, #T_e2855_row7_col15, #T_e2855_row9_col3, #T_e2855_row10_col26, #T_e2855_row11_col0, #T_e2855_row17_col26, #T_e2855_row19_col31, #T_e2855_row23_col35, #T_e2855_row34_col31, #T_e2855_row35_col26, #T_e2855_row35_col34 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_e2855_row0_col16, #T_e2855_row6_col9, #T_e2855_row13_col33, #T_e2855_row17_col33, #T_e2855_row18_col24, #T_e2855_row22_col25, #T_e2855_row25_col33, #T_e2855_row27_col24, #T_e2855_row32_col27, #T_e2855_row35_col24, #T_e2855_row35_col28 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_e2855_row0_col18, #T_e2855_row0_col21, #T_e2855_row2_col22, #T_e2855_row4_col7, #T_e2855_row5_col13, #T_e2855_row7_col4, #T_e2855_row7_col17, #T_e2855_row8_col17, #T_e2855_row13_col5, #T_e2855_row15_col7, #T_e2855_row16_col4, #T_e2855_row18_col2, #T_e2855_row21_col8, #T_e2855_row24_col22, #T_e2855_row26_col4, #T_e2855_row26_col7, #T_e2855_row27_col5, #T_e2855_row27_col8, #T_e2855_row27_col21, #T_e2855_row29_col5, #T_e2855_row32_col4, #T_e2855_row32_col7, #T_e2855_row32_col8, #T_e2855_row32_col13, #T_e2855_row32_col22, #T_e2855_row34_col17 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_e2855_row0_col19, #T_e2855_row1_col2, #T_e2855_row2_col1, #T_e2855_row2_col4, #T_e2855_row3_col6, #T_e2855_row3_col16, #T_e2855_row3_col22, #T_e2855_row6_col3, #T_e2855_row8_col7, #T_e2855_row9_col5, #T_e2855_row9_col36, #T_e2855_row10_col8, #T_e2855_row10_col36, #T_e2855_row12_col11, #T_e2855_row12_col13, #T_e2855_row12_col14, #T_e2855_row12_col17, #T_e2855_row12_col18, #T_e2855_row12_col20, #T_e2855_row12_col21, #T_e2855_row15_col11, #T_e2855_row15_col13, #T_e2855_row15_col14, #T_e2855_row15_col17, #T_e2855_row15_col18, #T_e2855_row15_col20, #T_e2855_row15_col21, #T_e2855_row24_col23, #T_e2855_row24_col25, #T_e2855_row25_col0, #T_e2855_row25_col24, #T_e2855_row27_col15, #T_e2855_row27_col26, #T_e2855_row27_col28, #T_e2855_row27_col29, #T_e2855_row28_col12, #T_e2855_row28_col18, #T_e2855_row28_col27, #T_e2855_row30_col31, #T_e2855_row30_col32, #T_e2855_row32_col30, #T_e2855_row36_col9, #T_e2855_row36_col10, #T_e2855_row36_col33, #T_e2855_row36_col34, #T_e2855_row36_col35 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_e2855_row0_col20, #T_e2855_row13_col1, #T_e2855_row14_col19, #T_e2855_row15_col27, #T_e2855_row21_col19, #T_e2855_row24_col8, #T_e2855_row27_col6, #T_e2855_row30_col11, #T_e2855_row31_col20, #T_e2855_row34_col6, #T_e2855_row36_col3 {
#   bac

# %%
def drop_correlated_columns(df: pd.DataFrame, cut_off: float = 0.8, to_drop:list[str]=None) -> tuple[pd.DataFrame,list[str]]:
    """
    Function to drop correlated columns of a Data Frame
    :param df: Data frame to be modified
    :param cut_off: Maximum allowed correlation
    :param to_drop: Columns to drop. By default, those with 0 variation
    :return: Data frame with deleted correlated columns, list of dropped columns
    """
    if to_drop is None:
        corr_matrix = df.corr('spearman').abs()
        upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(bool))
        to_drop = [column for column in upper.columns if any(upper[column] > cut_off)]
    df.drop(to_drop, axis=1, inplace=True)
    return df, to_drop

# %%
x_train, to_drop = drop_correlated_columns(x_train)

# %%
x_test = x_test[list(x_train.columns)]

# %%
#zapisy
x_train.to_csv('data/x_train.csv', index=False)
x_test.to_csv('data/x_test.csv', index=False)
